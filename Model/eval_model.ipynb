# %%
import sys
import os
# sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), "..")))
# from Rag.rag_pipeline import *
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, BitsAndBytesConfig
import torch

model_name = "VietAI/vit5-base"
saved_model_path = "./vit5-base-qa-final"

def get_response():
    question = "chào bạn"
    # Load tokenizer
    tokenizer = AutoTokenizer.from_pretrained(saved_model_path)

    # Load base model
    model = AutoModelForSeq2SeqLM.from_pretrained(saved_model_path, device_map="cpu")

    model.eval()
    context = ""

    if len(context) == 0:
        return "Xin lỗi! Câu hỏi bạn nằm ngoài sự hiểu biết của tôi."

    input_text = f"question: {question} context: {context}"

    inputs = tokenizer(input_text, return_tensors="pt", truncation=True, padding="max_length", max_length=2048)
    inputs = {k: v for k, v in inputs.items() if k != "token_type_ids"}

    with torch.no_grad():
        outputs = model.generate(**inputs, max_new_tokens=256)

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

get_response()
# Out:
# Intel Extension for PyTorch 2.7 needs to work with PyTorch 2.7.*, but PyTorch 2.5.1+cu121 is found. Please switch to the matching version and run again.
# None of the available devices `available_devices = None` are supported by the bitsandbytes version you have installed: `bnb_supported_devices = {'"cpu" (needs an Intel CPU and intel_extension_for_pytorch installed and compatible with the PyTorch version)', 'cuda', 'xpu', 'mps', 'hpu', 'npu'}`. Please check the docs to see if the backend you intend to use is available and how to install it: https://huggingface.co/docs/bitsandbytes/main/en/installation#multi-backend
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 35
#      31         outputs = model.generate(**inputs, max_new_tokens=256)
#      33     return tokenizer.decode(outputs[0], skip_special_tokens=True)
# ---> 35 get_response()
#
# Cell In[10], line 17, in get_response()
#      14 tokenizer = AutoTokenizer.from_pretrained(saved_model_path)
#      16 # Load base model
# ---> 17 model = AutoModelForSeq2SeqLM.from_pretrained(saved_model_path, device_map="cpu")
#      19 model.eval()
#      20 context = ""
#
# File ~/miniconda3/envs/mle/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:571, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     569     if model_class.config_class == config.sub_configs.get("text_config", None):
#     570         config = config.get_text_config()
# --> 571     return model_class.from_pretrained(
#     572         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     573     )
#     574 raise ValueError(
#     575     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     576     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     577 )
#
# File ~/miniconda3/envs/mle/lib/python3.10/site-packages/transformers/modeling_utils.py:279, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     277 old_dtype = torch.get_default_dtype()
#     278 try:
# --> 279     return func(*args, **kwargs)
#     280 finally:
#     281     torch.set_default_dtype(old_dtype)
#
# File ~/miniconda3/envs/mle/lib/python3.10/site-packages/transformers/modeling_utils.py:4228, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4225     hf_quantizer = None
#    4227 if hf_quantizer is not None:
# -> 4228     hf_quantizer.validate_environment(
#    4229         torch_dtype=torch_dtype,
#    4230         from_tf=from_tf,
#    4231         from_flax=from_flax,
#    4232         device_map=device_map,
#    4233         weights_only=weights_only,
#    4234     )
#    4235     torch_dtype = hf_quantizer.update_torch_dtype(torch_dtype)
#    4236     device_map = hf_quantizer.update_device_map(device_map)
#
# File ~/miniconda3/envs/mle/lib/python3.10/site-packages/transformers/quantizers/quantizer_bnb_4bit.py:84, in Bnb4BitHfQuantizer.validate_environment(self, *args, **kwargs)
#      81 from ..utils import is_bitsandbytes_multi_backend_available
#      83 bnb_multibackend_is_enabled = is_bitsandbytes_multi_backend_available()
# ---> 84 validate_bnb_backend_availability(raise_exception=True)
#      86 if kwargs.get("from_tf", False) or kwargs.get("from_flax", False):
#      87     raise ValueError(
#      88         "Converting into 4-bit or 8-bit weights from tf/flax weights is currently not supported, please make"
#      89         " sure the weights are in PyTorch format."
#      90     )
#
# File ~/miniconda3/envs/mle/lib/python3.10/site-packages/transformers/integrations/bitsandbytes.py:560, in validate_bnb_backend_availability(raise_exception)
#     557     return False
#     559 if is_bitsandbytes_multi_backend_available():
# --> 560     return _validate_bnb_multi_backend_availability(raise_exception)
#     561 return _validate_bnb_cuda_backend_availability(raise_exception)
#
# File ~/miniconda3/envs/mle/lib/python3.10/site-packages/transformers/integrations/bitsandbytes.py:517, in _validate_bnb_multi_backend_availability(raise_exception)
#     511     err_msg = (
#     512         f"None of the available devices `available_devices = {available_devices or None}` are supported by the bitsandbytes version you have installed: `bnb_supported_devices = {bnb_supported_devices_with_info}`. "
#     513         "Please check the docs to see if the backend you intend to use is available and how to install it: https://huggingface.co/docs/bitsandbytes/main/en/installation#multi-backend"
#     514     )
#     516     logger.error(err_msg)
# --> 517     raise RuntimeError(err_msg)
#     519 logger.warning("No supported devices found for bitsandbytes multi-backend.")
#     520 return False
#
# RuntimeError: None of the available devices `available_devices = None` are supported by the bitsandbytes version you have installed: `bnb_supported_devices = {'"cpu" (needs an Intel CPU and intel_extension_for_pytorch installed and compatible with the PyTorch version)', 'cuda', 'xpu', 'mps', 'hpu', 'npu'}`. Please check the docs to see if the backend you intend to use is available and how to install it: https://huggingface.co/docs/bitsandbytes/main/en/installation#multi-backend
